# %% [markdown]
# # Introduction to Networking
# ## 1. Communication
# Communication is the process of sharing information, ideas, or feelings between people (or groups) so that they understand each other.
# - Using signal
# - Via a medium
#
# ## 2. Information
# Any type of data that has been organized or processed so it has meaning and can be understood.
# - Text
# - Image
# - Audio
# - Video
#
# ## 3. Medium
# A path or channel through which a message travels from sender to receiver.
# - Wired
# - Wireless
#
# ## 4. Signal
# A **form** the message takes so it can move through the medium.
# - Analog
# - Digital
# - Electrical
# - Optiacal / Light
# - Radio Frequency
#
# ## 5. Electrical
# The branch of engineering that deals with devices and systems operating on high-power AC (alternating current) electricity, such as:
# - AC
# - TV
# - Refrigerator
# - Washing Machine
#
# ## 6. Electronic
#  The branch of engineering that deals with devices and systems operating *mainly* on low-power DC (direct current) electricity, often using semiconductors to process signals, such as:
#  - Mobile phones
#  - Laptops/Tabs
#  - Smartphones
#  - PC/Computer
#
# ## 7. Network
# Group of devices connected with each other
# - Bluetooth file sharing
# - Wifi
# - Internet
#
# > **Note:** Just connect two devices with each other, a basic network is formed
#
# ## 8. Types of network
# Depending upon the area, following are some of the main network types
# - PAN (Personal Area network) eg. bluetooth
# - LAN (Local Area Network) eg. Office Wifi router
# - CAN (Campus Area Network) / LAN (Local Area Network) eg. A university Network
# - MAN (Metropolitian Area Network) eg. Cable TV
# - WAN (Wide Area Network) eg. Company's branch office connected across different cities.
# - Internet: Biggest network
#
# ## 9. Protocols
# Set of rules and regulations to do something specific:
# - IP
# - MAC
# - DNS
# - HTTP / HTTPS
#
# ## 10. Cables
# Internet cables are the physical wires that carry data between devices, networks, and the internet. Some of them are
#
# - **Co-axial** (rarely used nowadays) - Often used by cable TV companies to deliever internet
#
# - **Twisted Pair** (mostly used in LAN)
#
# - **Fiber** (widely used in WAN)- Use light to send data extremely fast over long distances
#
# ## 11. Node
# All the devices in a network are nodes.
#
# ## 12. Topology
# The way devices are connected to each other
#
# ## 13. Bandwidth
# Maximum amount of data that can be transmitted in the network using a particular link
#
# ## 14. Speed
# The current use of bandwidth
# - Bandwidth = 50mbps
# - Speed = 40mbps
#
# ## 15. Types of network
# - Telecon (works on RF frequency singals)
# - Datacom networks (works on IP)
#
# ## 16. Network Models
# - Peer to Peer : one to one direct connection
# - Client Server : Internet
#
# ## 17. Communication types
# - Unicast
# - Multicast
# - Broadcast
#
# ## 18. Data transmission modes
# - Simplex: One device for one task and other device for other task, one way communication. eg. TV broadcast or FM broadcast
# - Half Duplex: One device for both task but one task at a time. Eg. Walkie talkie.
# - Full Duplex: One device for both tasks and both tasks at the same time. Eg. Video Call
#
# ---

# %% [markdown]
# # OSI Model
#
# ## Introduction to OSI Model
#
# - Developed by ISO - International Organization for standardization
#
# - Stands for - Open System Interconnect Model
#
# - Idea was to develop vendor independent hardware and software
#
# - Useful tool for network troubleshooting
#
# - **It just explain how internet works and how data flow in network**
#
# - Has no physical appearance in the network
#
# - Only used for teaching purpose
#
# ## OSI Architecture (7-layered architecture)
#
# |Layer|Name|
# |-----|----|
# |7|Application Layer|
# |6|Presentation Layer|
# |5|Session Layer|
# |4|Transport Layer|
# |3|Network Layer|
# |2|Data Link Layer|
# |1|Physical Later|
#
# > **Note:** These 7 layers are furthur divided into 2 more categories for the sake of simplicity:
#
# 1. **Upper Layers:** close to the user
#
# 2. **Lower Layers:** close to the network
#
#
# ### 1. Upper Layer
#
# |Layer|Name|
# |-----|----|
# |7|Application Layer|
# |6|Presentation Layer|
# |5|Session Layer|
#
# - These are the layers that generally deals with the applications only
# - They have no real involvement with the real data packaging or transportation
#
# ### 2. Lower Layer
#
# |Layer|Name|
# |-----|----|
# |4|Transport Layer|
# |3|Network Layer|
# |2|Data Link Layer|
# |1|Physical Later|
#
# - These layers actually deals with how data is really being transferred through the network.
# - Vast majority of network engineering is all about these lower layers.
# - You would be focusing on upper layers if you are more of a programmer and writing applications.
#
# > **Note:** Upper layers focus on **programming** and application-level functions, while the Lower layers handle the **actual transfer of data**.  In network engineering, the primary focus is on the lower layers.
#
# ## Functions of each OSI  layer
#
# | Layer|Function|
# | -----|--------|
# | **Application Layer**  | Provides a platform for network access to applications (e.g., web browsers, email clients). Provides network services like HTTP, SMTP, FTB, DNS              |
# | **Presentation Layer** | Handles data format, translation, compression and encryption/decryption (e.g., HTTPS encryption).                    |
# | **Session Layer**      | Establishes, manages, and terminates sessions between client and server, keeping them isolated. Handles synchronization.          |
# | **Transport Layer**    | Provides end-to-end communication with segmentation, flow control, error control, and port addressing (e.g., TCP, UDP), making sure data is sent and received correctly.       |
# | **Network Layer**      | Handles logical (IP) addressing, routing, packet sforwarding and selects the best path to the destination.                         |
# | **Data Link Layer**    |Facilitates node-to-node data transfer within the same network; handles framing, MAC addressing, flow control, and error detection (includes LLC and MAC sublayers)|
# | **Physical Layer**     | Facilitates physical transmission of raw bits; defines hardware, cabling, topology, signal encoding, bit rate, and synchronization|

# %% [markdown]
# ## 7. Application Layer
#
# - This layer provides an interface between the user and applications to access the network servies.
#
# - Eg.  web browsers, email clients, messaging apps (e.g., WhatsApp).
#
# - This is the layer which Communicates directly with end-user devices and applications.
#
# - Common protocols/services: HTTP, SMTP, FTP, Telnet.
#
# > **Note:** Networking is all about enabling applications to work and communicate over the network.
#
# ## 6. Presentation Layer
#
# - This layer makes sure that 2 end devices on the network can talk to each other and understand each other regardless of the operating systems , data formats or encryption types they are using.
#
# **Other functions**
#
# - Data encryption and decryption
#
# - Data compression and decompression
#
# - Data translation between formats
#
# - Data formatting and syntax handling
#
# ## 5. Session Layer
#
# - It handles the session between end hosts and web servers
#
# - Responsible for starting, maintaining, and terminating communication sessions between clients and servers.
#
# - Many web applications rely on sessions to track user activity and maintain connections.
#
# - Eg. When you are logged into Gmail or Facebook, you have an active session with their servers. Logging out ends the session, and logging in again creates a new session.
#
# > **Note:** In Windows CMD, typing ``NETSTAT`` will display the active sessions and connections on your system.
#
# ## 4. Transport Layer
#
# - It breaks large chunks of data into smaller units for transmission, since complete data cannot be sent as a single block over the network.
#
# - At the sending side, data is segmented; at the receiving side, these segments are reassembled into the original data.
#
# - This process is called **segmentation**, and the smaller units at this layer are known as **segments**. at transport layer.
#
# - **It establishes end-to-end connectivity between devices using port numbers.**
#
# - It ensures reliable or unreliable delivery depending on the protocol used (e.g., TCP for reliable, UDP for faster but unreliable).
#
# > **Header:** Each layer adds its own information with the main data in the form of header. It is known as header becuase it is processed before the main data.
#
# #### **Fig:** OSI Reference Model
#
# <img src="image/OSI1.png" width="500">
#
# > **Note:** Tailer is added in data link layer, for error checking
#
# - Ensure reliable data delivery via error detection and re-transmission (using TCP)
#
# - Multiplexing and demultiplexing using port numbers.
#
# - **Protocols Used:** TCP, UDP
#
# ### TCP
# - TCP is used for reliable connectivity (by TCP 3-way handshaking process)
# - eg. SMTP, FTP
#
# ### UDP
# - UDP is used for faster but unreliable communications
# - eg. Phone calls, Video Calls
#
# ### Port Numbers: Range (0 to 2¹⁶-1) (0 to 65535)
# - 0 to 1023 - Well-known ports (assigned to standard services).
# - 1024 to 64511 - Registered ports (used for general client-server sessions).
# - 64512 to 65535 - Dynamic or private ports.
#
# ### Socket = IP Address + Port Numbers
# - A unique combination of IP address + port number used to identify a specific connection.

# %% [markdown]
# ## 3. Network Layer
#
# - Provides connectivity between devices across different networks and determines - the best path for data transmission.
#
# #### Logical Addressing:
# - Assigns and uses IP addresses for device identification.
# - Supports both IPv4 and IPv6.
#
# #### Devices and Protocol at this layer
# - Devices: Router
# - Protocols: IPv4, IPv6, ICMP (Internet Control Message Protocol)
#
# > **Note:** In Windows CMD, type ``ipconfig`` to view your device’s IP address details.
#
# ## 2. Data Link Layer
# - It performs the final framing and formatting of data before sending it over the physical medium.
# - Responsible for node-to-node delivery within the same network segment.
#
# #### Define Physical Addressing:
# - Uses MAC (Media Access Control) addresses to identify devices on the local network.
#
# #### Control **Error Detection**:
# - Uses methods such as **Cyclic Redundancy Check (CRC)** to detect transmission errors.
#
# #### Device and Protocols at this layer:
# - **Devices:** Switches, bridges, wireless access points
# - **Protocols:** Ethernet, PPP (Point-to-Point Protocol)
#
# ## 1. Physical Layer
# Handles the transmission of raw bits over a physical medium.
# It defines physical properties of the network medium:
# - Electrical/optical signaling methods
# - Data transmission rates (bit rates)
# - Physical connectors and interfaces
# - Maximum cable lengths/distances
# - Optical wavelengths
# - Wireless frequencies
#
# #### Devices and media:
# - Hubs, repeaters
# - Ethernet (CAT) cables, fiber optic cables
# - Wireless antennas and transmitters

# %% [markdown]
# ## Why use layered architecture?
#
# #### 1. Devices only need to be aware of their own layer:
#
# - Web servers don’t care whether requests arrive via wired cables or wireless signals.
#
# - Switches don’t care whether they are forwarding IPv4 or IPv6 packets, as that’s handled by a higher layer.
#
# #### 2. Enables interoperability between devices and vendors:
#
# - Google Chrome can communicate with an Apache server because both follow HTML standards.
#
# - A Huawei Ethernet switch can connect to a D-Link Ethernet switch because they follow Ethernet standards.
#
# - A Cisco router can connect to a Juniper router because they follow the same IP routing standards.

# %% [markdown]
# ## Encapsulation:
# - The process of adding headers (and sometimes trailers) at each layer on the sending host to create a PDU (Protocol Data Unit).
# - It occurs as data moves down the OSI stack (Layer 7 → Layer 6 → Layer 5 → … → Layer 1).
# - At each step, the current layer adds its own control information before passing the data to the layer below.
# - The process repeats until the physical layer is reached for transmission.
#
# ## Decapsulation:
# - The process of removing headers/trailers at each layer on the receiving host to retrieve the original data from the PDU.
# - Occurs as data moves up the OSI stack (Layer 1 → Layer 2 → Layer 3 → … → Layer 7).
# - At each step, the current layer removes its own control information before passing the data to the layer above.
# - Repeats until the Application Layer is reached, delivering the original message to the user.
#
# <img src="image/OSI2.png" width="500">

# %% [markdown]
# ## Where is OSI helpful in real life?
# When troubleshooting a network problem we often go up the OSI model:
#
# **Physical**
# - Is the network cable plugged in?
# - Is the device powered on?
#
# **Data link**
# - Is the link light (LED on the port) active?
#
# **Network**
# - Are you getting a valid IP address?
#
# **Transport**
# - Can you ping your default gateway?
#
# **Session**
# - Do you have valid DNS server information?
# - Can you ping an external IP (e.g., 8.8.8.8) but not a domain name (e.g., www.google.com)?
#
# **Presentation & Application**
# - Can you open a website in your browser?

# %% [markdown]
# ---
# # TCP / IP Model
#
# - Full form: Transmission Control Protocol / Internet Protocol model
#
# - Purpose: A practical networking model with 4 layers (Link → Internet → Transport → Application).
#
# - Function: Defines how the internet actually works; protocols like TCP, IP, HTTP, FTP, DNS are based on it.
#
# - Implemented; created by DARPA for the ARPANET and now used globally.
#
# > **Note:** OSI is a theoretical model. TCP/IP is a practical model
#
# <img src="image/TCP1.png" width="500">
#
# | Protocol   | Port(s) | Function                                                       |
# | ---------- | ------- | -------------------------------------------------------------- |
# | **HTTP**   | 80      | Hypertext Transfer Protocol                                    |
# | **HTTPS**  | 443     | Secure HTTP (encrypted)                                        |
# | **FTP**    | 20, 21  | File Transfer Protocol (slow but secure)                       |
# | **TFTP**   | 69      | Trivial File Transfer Protocol (fast but insecure)             |
# | **SMTP**   | 25      | Simple Mail Transfer Protocol (sending emails)                 |
# | **POP3**   | 110     | Post Office Protocol (retrieving emails)                       |
# | **IMAP**   | 143     | Internet Message Access Protocol (retrieving emails with sync) |
# | **TELNET** | 23      | Remote login protocol (old and insecure)                       |
# | **SSH**    | 22      | Secure Shell (secure remote login)                             |
# | **DNS**    | 53      | Domain Name System (translates domain names to IPs)            |
# | **NTP**    | 123     | Network Time Protocol (synchronizes clocks)                    |
# | **NNTP**   | 119     | Network News Transfer Protocol (Usenet articles)               |
#
# - **HTTP -** to access website
# - **SMTP -** to send the mail
# - **POP -** to receive mail
# - **FTP -** to download the attachments

# %% [markdown]
# ## TCP vs UDP
#
# | TCP (Transmission Control Protocol)       | UDP (User Datagram Protocol)         |
# | ----------------------------------------- | ------------------------------------ |
# | Connection-oriented                       | Connectionless                       |
# | Uses 3-way handshake before data transfer | No handshake required                |
# | Slower (due to reliability checks)        | Faster (less overhead)               |
# | More reliable and secure                  | Less reliable, not inherently secure |
# | Supports windowing (flow control)         | No windowing (no flow control)       |
#
# > **Window Size:** Size of data that can be transmitted in a single segment. It can be changed in TCP but not in UDP
#
# <img src="image/TCP2.png" width="500">
#
# ### TCP/UDP Port Numbers: Range (0 to 2¹⁶-1) (0 to 65535)
# - 0 to 1023 - Well-known ports (assigned to standard services).
# - 1024 to 64511 - Public ports (used for general client-server sessions).
# - 64512 to 65535 - Dynamic or private ports (used for specific network applications).
#
# ### Socket = IP Address + Port Numbers
# - A unique combination of IP address + port number used to identify a specific connection.

# %% [markdown]
# ## MAC address - Media Access Control
# - Hardware or Physical address of a device in a network
# - Also known as BIA (Burn in Address)
# - It is Globally unique: one MAC address is never reused on another device anywhere in the world
# - If the device is faulty or corrupted, that MAC address is wasted.
# - It is of 48 bits and is written in **hexadecimal** number system (0–9, A–F).
# - It has 2 parts:  OUI (24 bits) + NIC Specific (24 bits)
#
# | **OUI** (Organizationally Unique Identifier)        | **NIC Specific**                                          |
# | --------------------------------------------------- | --------------------------------------------------------- |
# | 24 bits — identifies manufacturer (e.g., Dell, IBM) | 24 bits — unique ID for the device from that manufacturer |
#
#
#
# **For Example:** If Dell makes 1,000 laptops:
# - OUI identifies Dell
# - NIC part uniquely identifies each laptop’s MAC address
#
# > **Note:** On windows CMD, type ``getmac`` to get MAC address of the device.

# %% [markdown]
# # IP(Internet Protocol)
# - Provides logical addressing (IPv4 & IPv6) to uniquely identify devices on a network.
# - Responsible for routing packets from source to destination across networks.
# - Connectionless: Sends packets (called datagrams) independently, without guaranteeing delivery.
#
# #### **IPv4**
# - It is a 32 bit logical address, represented in **Dotted Decimal Notation**.
# - 4 octets (8-bit blocks) separated by dots (.) e.g., 192.168.1.1
# - 32-bit addressing → ~4.3 billion unique addresses
# - Address shortage problem
#
# #### **IPv6**
# - It is a 128 bit logical address.
# - 8  hextets (16-bit blocks) separated by colons (:) e.g.,2001:0db8:85a3::8a2e:0370:7334
# - 128-bit addressing → ~3.4 × 10³⁸ unique addresses (almost unlimited)
# - Solves shortage, faster routing, better security

# %% [markdown]
# #### IANA - Internet Assigning Number System
# - Responsible for managing (assigning) key internet number resources.
# - For ex. IP, MAC, ASN
#
# #### IETF - Internet Engineering Task Force
#
# #### ISOC - Internet Society
# - Supports and promotes the development and open use of the internet.
#
# #### IAB - Internet Architecture Board
#
# #### IEEE- Institute of Electrical and Electronic Engineering
# - Develops global standards for electrical, electronics, and related technologies.
# - Examples: Ethernet (IEEE 802.3), Wi-Fi (IEEE 802.11).

# %% [markdown]
# > **Note:**
#
# - IANA divides the world into RIRs (Regional Internet Registries), for IP distribution.
# - Each RIR is responsible for distributing IP addresses within its region.
# - India falls under **APNIC** – Asia Pacific Network Information Centre.
# - This is the hierarchy by which IP addresses are allocated.
#
# ```txt
#             IANA
#              |
#             RIR
#              |
#             Tier 1 ISP
#             (Jio)
#              |
#             Tier 2 ISP
#             (Airtel)
#              |
#             Tier 3 ISP
#              |
#             User
#
# ```

# %% [markdown]
# ---
# ## IP Address Classes
#
# | 1st Octet | 2nd Octet | 3rd Octet | 4th Octet |
# | --------- | --------- | --------- | --------- |
# | 2⁸        | 2⁸        | 2⁸        | 2⁸        |
# | 256       | 256       | 256       | 256       |
# | 0–255     | 0–255     | 0–255     | 0–255     |
#
# #### Range of IP
# - Minimum = 0.0.0.0
# - Maximum = 255.255.255.255
#
# ### 5 Classes of IP Address
#
# | Class   | 1st Octet | First IP  | Last IP         |
# | ------- | --------- | --------- | --------------- |
# | Class A | 0 – 127   | 0.0.0.0   | 127.255.255.255 |
# | Class B | 128 – 191 | 128.0.0.0 | 191.255.255.255 |
# | Class C | 192 – 223 | 192.0.0.0 | 223.255.255.255 |
# | Class D | 224 – 239 | 224.0.0.0 | 239.255.255.255 |
# | Class E | 240 – 255 | 240.0.0.0 | 255.255.255.255 |
#
# <img src="image/IP1.png" width="500">
#
# #### IP address classes divide addresses into two parts:
#
# 1. **Network Address**
# - Identifies the network and is used by networking devices such as routers.
# - In Network Id/Address all Host bits are 0.
# - Eg. 192.168.10.0
#
# 2. **Host Address**
# - Identifies individual devices within the network, such as PCs or servers.
# - Eg. 192.168.10.5

# %% [markdown]
# ### Class A
#
# | Class A               | N.H.H.H                                                   |
# | --------------------- | --------------------------------------------------------- |
# | Network Bits          | 8                                                         |
# | Host Bits             | 24                                                        |
# | Total Hosts           | 2^24                                                    |
# | Valid Address Range   | 1.0.0.0 to 126.255.255.255                                |
# | Private Address Range | 10.0.0.0 to 10.255.255.255                                |
# | Default Subnet        | 255.0.0.0                                                 |
# | Reserved Addresses    | 0.0.0.0 for default route, 127.X.X.X for loopback testing |
#
# - Class A address is used by very big enterprise networks.
#
# |N|H|H|H|
# |-|-|-|-|
# |8bit|8bit|8bit|8bit|
#
#
# #### Network ID
# - If given, **IP address of a device** is ``10.25.37.89`` (Class A)
#
# - Then its **Network ID** would be ``10.0.0.0`` (all Host bit =0)
#
# - That means any IP from ``10.0.0.1 to 10.255.255.254`` is part of that same network.
#
# #### Broadcast
# - When **all host bits are set to 1**, the address becomes the broadcast address.
#
# - If **Network address** is ``10.0.0.0``
#
# - Then ``10.255.255.255`` can be used as the destination IP to broadcast to all hosts within that network.

# %% [markdown]
# ### Class B
#
# | Class B               | N.N.H.H                                                   |
# | --------------------- | --------------------------------------------------------- |
# | Network Bits          | 16                                                        |
# | Host Bits             | 16                                                        |
# | Total Hosts           | 2^16 addresses              |
# | Valid Address Range   | 128.0.0.0 to 191.255.255.255                              |
# | Private Address Range | 172.16.0.0 to 172.31.255.255                              |
# | Default Subnet        | 255.255.0.0                                               |
# | Reserved Addresses    | — (no special large reserved block besides private range) |
#
# - Network and Host bit
#
# |N|N|H|H|
# |-|-|-|-|
# |8bit|8bit|8bit|8bit|
#
#
# - When we change the network part a new network is created.
# - When we change the host part a new host is created.
#
# <img src="image/IP2.png" width="500">

# %% [markdown]
# ### Class C
#
# | Class C               | N.N.N.H                                                   |
# | --------------------- | --------------------------------------------------------- |
# | Network Bits          | 24                                                        |
# | Host Bits             | 8                                                         |
# | Total Hosts           | 2^8 addresses                                             |
# | Valid Address Range   | 192.0.0.0 to 223.255.255.255                              |
# | Private Address Range | 192.168.0.0 to 192.168.255.255                            |
# | Default Subnet        | 255.255.255.0                                             |
# | Reserved Addresses    | — (no special large reserved block besides private range) |
#
#
#
# - Network and Host bit
#
# | N    | N    | N    | H    |
# | ---- | ---- | ---- | ---- |
# | 8bit | 8bit | 8bit | 8bit |

# %% [markdown]
# ### Class D & E (Reserved IP)
# - Class D and E are not used for standard unicast addressing.
#
# - **Class D - Reserved for Multicasting**
#
# - **Class E - Reserved for Experimental Address format**

# %% [markdown]
# ## What is Subnet Mask?
# * A subnet mask is a **32-bit number** that works alongside an IP address.
#
# * It tells us, which part of the IP address represents the **network** and which part represents the **host**.
#
# * In subnet mask, all **networks bits = 1** and all **host bits = 0**
#
# | Class | First Octet Range | Default Subnet Mask | CIDR Notation |
# | ----- | ----------------- | ------------------- | ------------- |
# | A     | 1 – 126           | 255.0.0.0           | X.0.0.0/8            |
# | B     | 128 – 191         | 255.255.0.0         | X.X.0.0/16           |
# | C     | 192 – 223         | 255.255.255.0       | X.X.X.0/24           |
#
#
# <img src="image/IP3.png" width="500">

# %% [markdown]
# ### Reserved IP Addresses
#
# 1. **Default Route** : ``0.0.0.0``
# Used to represent “any” address when a device doesn’t yet have an IP or when setting up routing rules.
#
# 2. **Loopback Address** : ``127.0.0.1``
# Used by a computer to talk to itself for testing and troubleshooting.
#
# 3. **Link Local Routing or APIPA** : ``169.254.0.0``
# Automatically assigned when a device can’t get an IP from a DHCP server. Works only within the local link.
#
# 4. **Multicast Address** : ``224.0.0.0 to 239.255.255.255``
# Used to send data to multiple devices at once.
#
# 5. **Future Usable Addess** : ``240.0.0.0 to 255.255.255.255``
# Set aside for potential future networking purposes.
#
# 6. **Universal IP Address** : ``127.0.0.0``
#
# ### Loopback IP Address
#
# - The loopback IP (127.0.0.1) is reserved for local host communication.
# - Loopback helps in troubleshooting - It’s a way to check if your computer’s TCP/IP stack — the networking brain of your OS — is working properly.
# - 127.0.0.1 works without any network connection because it’s purely internal to your computer.
#
# #### How to check if my local host is connection ready (Loopback Testing)?
# Open Command Prompt on Windows. Type ``ping 127.0.0.1``
#
# - If all packets are sent and received successfully → your network software is working.
#
# - If packets fail → something’s wrong with your local TCP/IP configuration.
#
#
# #### What if loopback testing fails?
#
# - If the loopback test fails, it means your computer’s TCP/IP stack is broken or disabled.
#
# - Without a working TCP/IP stack, your system can’t use IP networking at all — so you won’t be able to assign a functional IP address, connect to other devices, or access the internet.
#
# - This is true **even** if your physical network connection (Wi-Fi/Ethernet) is fine.
#
# #### What does `ping` do?
# Think of ``ping`` like sending a short “Hello, are you there?” message to an IP address.
#
# - If the address replies → it’s reachable.
#
# - If there’s no reply → the device is offline, unreachable, or the address is invalid.

# %% [markdown]
# ## Types of IP Address
# ### 1. On the basis of configuration
# 1. **Static**
# - An IP address that is manually assigned to a device and doesn’t change over time.
# - Manually configured by a network admin or user.
# - Used in small scale networks, not convenient for bigger networks.
# - Permanent and consistent.
#
# 2. **Dynamic**
# - An IP address that is automatically assigned by a DHCP (Dynamic Host Configuration Protocol) server and can change over time.
# - Automatically assigned by a router or DHCP server.
# - Used in large networks.
# - Temporary and may change periodically.
#
# > **Note:** A DHCP server (Dynamic Host Configuration Protocol server) is a network server that automatically assigns IP addresses and other network configuration settings (like subnet mask, gateway, and DNS servers) to devices on a network.
#
# #### APIPA Address (Automatic Private IP Addressing)
# - APIPA is also called link-local address.
# - Automatically assigned when a device can’t get an IP from a DHCP server. Works only within the local link.
# - It's range ``169.254.0.1 to 169.254.255.254``
# - Its main purpose is, it allows devices on the same local network to communicate even if there is no DHCP server.
#
# ### 2. On the basis of availablity
# 1. **IPv4**
# 2. **IPv6**
#
# ### 3. On the basis of network type
# 1. **Public**
# - To avoid network wastage, we differentiate IP as public and private IP.
# - Public IP are unique, whereas Private IP are reusable.
# - Public IP are used in WAN, and are provided by ISP (Internet Service Provider)
# - Each customer need to have a unique public ip address for the proper functioning of internet.
#
# 2. **Private**
# - Private addresed need not to be unique. Same IP scheme can be used in multiple networks.
# - Some of the IP ranges have been reserved as private IP range.
#
# #### **Class A** private IPs
# - (1 network)  ``10.0.0.0``. Range = ``10.0.0.0 to 10.255.255.255``
# - 10.255.255.255 = Broadcasrt Address
# - 10.0.0.0 = Network ID (Address)
# - Total IP = 2^24
# - Valid IP = 2^24 -2
#
# #### **Class B** private IPs
# - (16 Networks)
# - ``172.16.0.0``. Range = ``172.16.0.0 to 172.16.255.255``
# - ``172.17.0.0``. Range = ``172.17.0.0 to 172.17.255.255``
# - ``172.18.0.0``. Range = ``172.18.0.0 to 172.18.255.255``
# - . . .
# - ``172.31.0.0``. Range = ``172.31.0.0 to 172.31.255.255``
#
# #### **Class C** private IPs
# - (256 networks)
# - ``192.168.0.0``. Range = ``192.168.0.0 to 192.168.0.255``
# - ``192.168.1.0``. Range = ``192.168.1.0 to 192.168.1.255``
# - ``192.168.0.0``. Range = ``192.168.2.0 to 192.168.2.255``
# - . . .
# - ``192.168.255.0``. Range = ``192.168.2.0 to 192.168.255.255``
#
# ---

# %% [markdown]
# # Subnetting
# It is the process of dividing a single network into multiple sub-networks by borrowing bits from host field and moving them to network field.
# - The result is more number of sub-networks with less number of hosts per subnet.
# - Note: It doesn't give more host, infact it cost 2 extra host per subnet (1-broadcast and 1 for network address)
#
# - It Save address spaces, security, and traffic control etc.
#
# Part of IP address without subnetting
# |Network|Host|
# |-------|-----|
#
# Part of IP address with subnetting
# |Network|Subnetwork|Host|
# |-----|----------|------|
#
# <img src="image/Subnet1.png" width="500">
#
# Subnetting also provides security and controls traffic..
#
# <img src="image/Subnet2.png" width="500">
#
#
# ## Conditions for subnetting?
# 1. Subnetting according to the requirement of the subnetwork.
# 2. Subnetting according to the requirement host of the subnetwork.
#
# ## Complete process of subnetting
# Subnetting is a 5 step process.
# 1. Find new subnet mask
# 2. Find total no of new subnetworks.
# 3. Find total no of ip address or host per subnet
# 4. Find inverse IP / block size
# 5. Find subnet range.
#
# ### ``192.168.250.0/24``
# - Network bits = ``24``
# - Host bits = ``8``
# - Network bit represented by ``1``
# - Host bit represented by ``0``
# - ``11111111.11111111.11111111.00000000``
#
#
# #### 1: Subnetting according to the requirement of the subnetwork.
#
# - **Subnetwork required** = ``4``
# - Host = ``50``
#
# | Power of 2 | Value |
# | ---------- | ----- |
# | 2^8        | 256   |
# | 2^7        | 128   |
# | 2^6        | 64    |
# | 2^5        | 32    |
# | 2^4        | 16    |
# | 2^3        | 8     |
# | 2^2        | 4     |
# | 2^1        | 2     |
#
# - So if ``4`` subnetwork are required so we will shift ``2 bits`` (2^2 = 4) from Host to Network Part
#
# | Before                              | After                               |
# | ----------------------------------- | ----------------------------------- |
# | 11111111.11111111.11111111.00000000 | 11111111.11111111.11111111.11000000 |
# | Network bits = 24                   | Network bits = 26                   |
# | Host bits = 8                       | Host bits = 6                       |
# | Prefix notation = /24               | Prefix notation = /26               |
#
#
# - Total Host per network (IP)= 2^OFF bits = 2^6 = 64
# - Total Valid Host (Valid IP)= 2^off bits - 2 = 2^6 - 2 = ``62``
#
# - Total Subnetwors = 2^no of new ON bits = 2^2 = 4
# - Total valid subnetworks = 2^no of new ON bits = 2^2 = ``4``
#
# #### 2: Subnetting according to the requirement of the host per subnetwork.
#
# - **Host required** = ``5``
# - Subnetwork = ``25``
#
#
# - So if ``5`` hosts are required per network so we will OFF ``3 bits`` (2^3 = 8 > 5) and shift other bits to subnetwork bits (Make it ON)
#
# | Before                              | After                               |
# | ----------------------------------- | ----------------------------------- |
# | 11111111.11111111.11111111.00000000 | 11111111.11111111.11111111.11111000 |
# | Network bits = 24                   | Network bits = 29                   |
# | Host bits = 8                       | Host bits = 3                       |
# | Prefix notation = /24               | Prefix notation = /29               |
#
#
# - Total Host per network (IP)= 2^OFF bits = 2^3 = ``8``
# - Total Valid Host (Valid IP)= 2^off bits - 2 = 2^3 - 2 = ``6``
#
# - Total Subnetwors = 2^no of new ON bits = 2^5 = ``32``
# - Total valid subnetworks = 2^no of new ON bits = 2^5 = ``32``

# %% [markdown]
# ---
#
# ### Problem 1: Calculate subnet mask of ``10.0.0.1/19``
#
# - Network Bit = 19 (8+8+3)
# - Host Bit = 13 (5+8)
#
# - ``11111111.11111111.11100000.00000000``
#
# | Network Bit | Host Bit |
# |-------------|----------|
# | 11111111.11111111.111 | 00000.00000000 |
#
# - **Subnet Mask:** All Network Bit = 1 & All Host Bit = 0
# - **Subnet Mask =** ``255.255.224.0``

# %% [markdown]
# ### Problem 2: A company needs to subnet its network in such a way that, they must have at least 25 subnets and each subnet should have at least 5 hosts. Given IP ``192.168.10.0/24``.
#
# #### Condition 1: **Host >= 5**
# - Formula: ``Number of Hosts = 2^(OFF Bits) − 2 (subtract 2 for network + broadcast addresses).``
# - We need at least 5 usable hosts.
# - Check
#     - ``2^2 − 2 = 2``   → too small
#     - ``2^3 − 2 = 6``   → works (``6 hosts ≥ 5 needed``)
#
# - Subnet Mask
#     - ``11111111.11111111.11111111.11111000``
#     - ``255.255.255.248``
# - CIDR (Remaning for network bits)
#     - `/29`
#
# ### Condition 2: **Subnet >= 25**
# - Total Host bit = 3
# - Remaning network bit =  29
# - It belongs to class C (/24), remaning for subnet = 5
# - ``2^5 = 32 >= 25``. Hence we can successfully subnet the following IP such that, we can have 25 subnets with atleast 5 host per subnet.
#
# ### Final Answer
# - Subnet Mask: ``255.255.255.248``
# - CIDR: ``/29``
# - No of subnets: ``32``
# - Usable hosts per subnet: ``6``
#
#
# > **Note:**  Focus on minimizing the wastage of host IP addresses(host), not the number of networks. Unused networks can be used elsewhere.

# %% [markdown]
# ### Problem 3: ``192.168.50.0``, Need subnet atleast 100. Need Host atleast 2
#
# #### Condition 1: **Host >= 2**
# - Formula- ``No of Host = 2^OFF bits-2``
# - We need at least 2 usable hosts.
# - Check
#     - ``2^1 − 2 = 0``   →
#     - ``2^2 − 2 = 2``   → works
#
# - Subnet Mask
#     - ``11111111.11111111.11111111.11111100``
#     - ``255.255.255.252``
# - CIDR (Network Bit)
#     - `/30`
#
#
# ### Condition 2: **Subnet >= 100**
# - Total bits = ``32``
# - Host bits = ``2`` → Network + Subnet bits = ``30``
# - Class C network → Original network bits = ``24``
# - Subnet bits available = ``30 − 24 = 6``
# - Number of subnets: ``2^6 = 64`` → **Not enough (need 100)**.
#
# ### Final Answer
# - It’s not possible to have 100 subnets and at least 2 hosts per subnet for a single Class C network ``(/24)``.
# - Even at ``/30``, the maximum subnets you can create from ``/24`` is ``64``.

# %% [markdown]
# ---
# ### Calculate Block Size. (Wildcard Mask) (IP Range)
#
# ```txt
#   Total Subnet Mask     255.255.255.255
#   - New Subnet Mask    -255.255.255.192
#                        -----------------
#                          0 . 0 . 0 . 63
# ```
#
# ### Subnet Ranges..
#
# #### First subnet
# - Network ID: ``192.168.250.0``
# - Broadcast: ``192.168.250.63``
# - Usable hosts: ``192.168.250.1 – 192.168.250.62``
#
# #### Second subnet
# - Base network id + IP range (192.168.250.64 + 0.0.0.64)
# - `192.168.250.64 - 192.168.250.127`
#
# #### Third Subnet
# - Base network id + IP range (192.168.250.128 + 0.0.0.64)
# - `192.168.250.128 - 192.168.250.191`
#
# #### Fourth Subnet
# - Base network id + IP range (192.168.250.192 + 0.0.0.64)
# - `192.168.250.192 - 192.168.250.255`

# %% [markdown]
# ## Subnetting in Class C
#
# | IP/prefix       | Subnet Mask (Binary)                | Subnet Mask (Decimal) | Borrowed bits | Subnets | Host bits | Total hosts | Usable hosts | Block size (increment) | Wildcard mask (IP Range / Inverse IP) |
# | --------------- | ----------------------------------- | --------------------- | ------------: | ------: | --------: | ----------: | -----------: | ---------------------: | ------------- |
# | 192.168.50.0/25 | 11111111.11111111.11111111.10000000 | 255.255.255.128       |             1 |       2 |         7 |         128 |          126 |                    128 | 0.0.0.127     |
# | 192.168.50.0/26 | 11111111.11111111.11111111.11000000 | 255.255.255.192       |             2 |       4 |         6 |          64 |           62 |                     64 | 0.0.0.63      |
# | 192.168.50.0/27 | 11111111.11111111.11111111.11100000 | 255.255.255.224       |             3 |       8 |         5 |          32 |           30 |                     32 | 0.0.0.31      |
# | 192.168.50.0/28 | 11111111.11111111.11111111.11110000 | 255.255.255.240       |             4 |      16 |         4 |          16 |           14 |                     16 | 0.0.0.15      |
# | 192.168.50.0/29 | 11111111.11111111.11111111.11111000 | 255.255.255.248       |             5 |      32 |         3 |           8 |            6 |                      8 | 0.0.0.7       |
# | 192.168.50.0/30 | 11111111.11111111.11111111.11111100 | 255.255.255.252       |             6 |      64 |         2 |           4 |            2 |                      4 | 0.0.0.3       |

# %% [markdown]
# ## Subnet in Class B
#
# ### ``172.20.0.0/16``
#
# - Network Bits = 16
# - Host Bits = 16
# - ``111111111.11111111.00000000.00000000``
# - ``255.255.0.0``
# - Network ID = ``172.20.0.0``
# - Broadcast ID = ``172.20.255.255``
# - Inverse IP (Wildcard IP) = Network IP to Broadcast IP = ``172.20.0.0 - 172.20.255.255 = 0.0.255.255``
# - Valid Inverse IP(IP Range) = ``172.20.0.1 - 172.20.255.254 = 0.0.255.253``

# %% [markdown]
# ## Problem 1: In a class B IP, A company needs to subnet its network that it require 100 subnets and there should be at least 100 hosts per subnet. How would you complete the task?
#
# - Step 1: Find new subnet mask
# - Step 2: Find total no of subnets
# - Step 3: Find total no of hosts per subnet
# - Step 4: Find new IP range(Wildcard IP)
# - Step 5: Find Subnet Range
#
# ### Condition 1: **Host >= 100**
# - Formula- ``No of Host = 2^OFF bits-2``
# - We need at least 100 usable hosts.
# - Check
#     - ``2^6 − 2 = 62``   →
#     - ``2^7 − 2 = 126``   → works
#
# - Subnet Mask
#     - ``11111111.11111111.11111111.10000000``
#     - ``255.255.255.128``
# - CIDR (Network Bit)
#     - `/25`
#
#
# ### Condition 2: **Subnet >= 100**
# - Total bits = ``32``
# - Host bits = ``7`` → Network + Subnet bits = ``25``
# - Class B network → Original network bits = ``16``
# - Subnet bits available = ``25 − 16 = ``9``
# - Number of subnets: ``2^9 = 512`` → Satisfied.
#
# ### Wildcard IP / New IP Range / Block size
# - ``255.255.255.255 - 255.255.255.128 = 0.0.0.127``
#
# ### Subnet Range
#
# - First Subnet: ``172.20.0.0 - 172.20.0.127``
# - Second Subnet: ``172.20.0.128 - 172.20.0.255``
# - Third Subnet: ``172.20.1.0 - 172.20.01.127``
# - Fourth Subnet: ``172.20.1.128 - 172.20.1.255``
# - . . .
# - 512th Subnet: ``172.20.255.128 - 172.20.255.255``

# %% [markdown]
# ## Subnetting in Class A
#
# ### ``10.0.0.0/8``
# - Network Bits = 8
# - Host Bits = 24
# - ``111111111.000000000.00000000.00000000``
# - ``255.0.0.0``
# - Network ID = ``10.0.0.0``
# - Broadcast ID = ``10.255.255.255``
# - Inverse IP (Wildcard IP) = Network IP to Broadcast IP = ``10.0.0.0 - 10.255.255.255 = 0.0.255.255``
# - Valid Inverse IP(IP Range) = ``10.10.0.1 - 10.255.255.254 = 0.255.255.253``

# %% [markdown]
# ### ``10.0.0.0/11``
#
# ### Step 1: Find new subnet mask
# ``255.224.0.0``
#
# ### Step 2: Find total no of subnets
# - New ON bits = 2
# - Total subnets 2^3 = 8
#
# ### Step 3: Find total no of hosts per subnet
# - 2^OFF bits = 2^21
#
# ### Step 4: Find new IP range(Wildcard IP)
# - 0.31.255.255
#
# ### Step 5: Find Subnet Range
# - First subnet: ``10.0.0.0 to 10.31.255.255``
# - Second subnet: ``10.32.0.0-10.63.255.255``
# - Third subnet: ``10.63.0.0-10.94.255.255``
# - . . .
# - Fourth Subnet: ``10.224.0.0-10.255.255.255``

# %% [markdown]
# ### Difference between FLSM(Fixed length Subnet Mask) & VLSM(Variable Length SUbnet Mask)
#
#
# #### **VLSM** example: ``192.168.10.0``. For 5 subnets, Host required 2, 7, 25, 50, 100 (All variable size hosts).
#
# > **Note:** VLSM subnetting is started with the highest no of hosts required.
#
# ##### Subnet 1. For 100 hosts.
# - OFF Bits = 7 (as 2^7=128>100)
# - ON Bits = 25
# - New ON Bit = 1
# - Block size = 0.0.0.127
# - Prefix Notation: ``192.168.10.0/25``
# - Broadcast Address = ``192.168.10.128``
# - Range: ``192.168.10.0 to 192.168.10.127``
#
# ##### Subnet 2. For 50 hosts.
# - OFF Bits = 6 (as 2^6=64>50)
# - ON Bits = 26
# - New ON Bit = 2
# - Block Size = 0.0.0.63
# - Prefix Notation: ``192.168.10.128/26``
# - Broadcast Address = ``192.168.10.192``
# - Range = ``192.168.10.128 - 192.168.10.191``
#
# ##### Subnet 3. For 25 hosts.
# - OFF Bits = 5 (as 2^5=32>25)
# - ON Bits = 27
# - New ON Bit = 3
# - Block Size 0.0.0.31
# - Prefix Notation: ``192.168.10.192/27``
# - Broadcast Address = ``192.168.10.224``
# - Range = ``192.168.10.192 - 192.168.10.223``
#
# ##### Subnet 4. For 7 hosts.
# - OFF Bits = 4 (as 2^4-2=14>7)
# - ON Bits = 28
# - New ON Bit = 4
# - Block Size 0.0.0.15
# - Prefix Notation: ``192.168.10.224/28``
# - Broadcast Address = ``192.168.10.240``
# - Range = ``192.168.10.224 - 192.168.10.239``
#
# ##### Subnet 5.  For 2 hosts.
# - OFF Bits = 2 (as 2^2-2=2=2)
# - ON Bits = 30
# - New ON Bit = 2
# - Block Size 0.0.0.3
# - Prefix Notation: ``192.168.10.240/30``
# - Broadcast Address = ``192.168.10.244``
# - Range = ``192.168.10.240 - 192.168.10.243``

# %% [markdown]
# ##### **Ques 1.** The process of subnetting refers to?
# - **Stealing bits from the host portion of the address to create more sub networks.**
#
# ##### **Ques 2.** What is the purpose of a subnet mask in an IP address and mask combination?
# - **To delineate the network portion of the address from the host portion.**
#
# ##### **Ques 3.** Which statement about the VLSM is correct?
# - **It is not possible to use /31 mask in production**
# - When you use VLSm, you must taking an unused subnet and furthur subnetting it,
# - You can create subnets of just the right size with VLSM.
# - VLSM helps with summarization in networks.
#
# > **Explanation:** Many routers in production can use a /31 mask.  This is often done on WAN links where no more than two nodes are addressed in the subnet.
#
# ##### **Ques 4.** Which command is used on windows cmd to find your IP address?
# - **ipconfig**
#
# ##### **Ques 5.** How many bits are in one of the four octets of an IP address?
# - **8**
#
# ##### **Ques 6.** What is the default subnet mask for a class B address?
# - **255.255.0.0**
#
# ##### **Ques 7.** You are using a subnet mask subnetting scheme that contains 28 bits. How many host bits are there for host addressing
# - **4**
#
# ##### **Ques 8.** The broadcast address of a subnet is the next subnet address minus what?
# - **Current broadcast ID = Next Network Address - 1**
#
# ##### **Ques 9.** You have been allocated a class A network address of 29.0.0.0, you need to create at least 20 networks and each network will suppport a maximum of 160 hosts. Which of these subnet mask will work? 255.255.0.0 or 255.255.255.0
# - **Yes both would work.**
#
# Check: ``255.255.255.0``
# - Host = 100 minimum :: Host bit = 8 (as 2^8=256). 8 bit will easily accomodate 160 hosts.
# - Network bit = 24 :: 24 bit can easily accomodate 160 networks.
#
# Check: ``255.255.0.0``
# - Host = 100 minimum :: Host bit = 16 bit will easily accomodate 160 hosts.
# - Network bit = 16 :: 16 bit can easily accomodate 160 networks.
# - **/16 is possible, but it is not recommended as, there will be so much wastage of IP addresss.**
#
# ##### **Ques 10.** You have been allocated a class B network address of 135.1.0.0 and need to create 4 subnets with around 200 hosts. What is the easiest mask to use to satisfy the criteria
# - For 200 hosts and 4 subnets. 8 bit will be used for host bit.
# - In class B, 16bit is for network bit, so 32-8 =8 bit will be used for subnet. (More than enough for subnets)
# - Subnet mask= 255.255.255.0
# - CIDR ``/24``
#
# ##### **Ques 11.** Write the IP address 222.1.1.20 mask 255.255.255.192 in CIDR notation.
# - 11111111.11111111.11111111.11000000
# - CIDR = /26
# - Prefix Notation: ``222.1.1.20/26``
#
# ##### **Ques 12.** What is the IP address 135.1.1.25 mask 255.255.248.0 in CIDR notation.
# - Prefix Notation: ``135.1.1.25/21``
#
# ##### **Ques 13.** You have been allocated a class C network address of 211.1.1.0 and are using the default subnet mask of 255.255.255.0, how many hosts can you have?
# - For class C, we can have 8 bits for hosts.
# - **Total host = 2^8-2 = 254hosts.**
#
# ##### **Ques 14.** Subnet the class C IP address 195.1.1.0, so that you have 10 subnets each with a maximum 12 hosts on each subnet. List the address on host 1 on subnet 0, 1, 2, 3, 10. Current mask = 255.255.255.0
# - Bits needed for 10 subnets = 4 = 2^4 = 16 possible subnets.
# - Bits needed for 12 hosts = 4 = 2^4-2 = 16-2 = 14 possible hosts.
# - So, our mask in binary = 11110000 = 240(in decimal)
# - Final Mask = 255.255.255.240
#
#
# ##### **Ques 15.** Subnet the class C IP address 205.11.2.0, so that you have 30 subnets. What is the subnet mask for the maximum munbers of hosts? How many hosts can each subnet have? What is the IP address of host 3 on subnet 2?
# - Current mask = 255.255.255.0
# - Bits needed for 30 subnet = 5 = 2^5=32 possible subnets
# - Bits left for hosts = 3 = 2^3-2 = 6 possible hosts.
# - So, our mask in binary = 11111000 = 248(in decimal)
# - Final mask = 255.255.255.248
# - CIDR /29
# > **Important question:**
# - **Address of host 3 on subnet 2 is**
#     - **subnet 2 = 00010 000** (5 bit subnet)
#     - **host 3 = 00000 011** (3 bit host)
#     - **address = 00010 011 (19 in decimal)**
#     - **IP address = 205.11.2.19**
#
#
# ##### **Ques 16.**  Subnet the Class C IP address, so that you have at least 2 subnets each subnet must have room for 48 hosts WHat are the two possible subnet mask?
#
# - Current subnet mask
# - Bit needed for 48 hosts = 6 (2^6=64-2=62)
# - Bit needed for 2 subnet = 1 (2^1 = 2)
# - Total of 7 bits needed, therefore we can use either 1 bit or 2 bits for the subnet. So, we could have 1 bit subnet 7 bit host or 2 bit subnet 6 bit host.
# - Final mask possible are ``255.255.255.128`` and ``255.255.255.192``
#
# ##### **Ques 17.** What valid host range in the IP address 172.21.81.174/24 a part of?
# - /24 = Class B
# - Host bit 8. Range 172.21.81.0 to 172.21.81.255
# - Valid range = ``172.21.81.1 to 172.21.81.254``
#
# ##### **Ques 18.**  How many subnets and hosts per subnet can you get from the network 172.26.0.0/23?
# - CIDR = /23
# - Host bit = 9:: Possible hosts = 2^9-2 = 510 hosts
# - Subnet bit = 7:: Possible subnet = 2^7 = 128 subnet
#
# > **Note:** Bitwise AND of IP address and Subnet Mast gives Network ID ***(which network the host belongs)***
#
# #### **Ques 19.** What is the broadbcast address of hte network 172.29.248.0, given mask 255.255.254.0?
#
# |  `172.29.248.0` | `172.29.(11111000).00000000`  |
# | --------------: | :---------------------------- |
# | `255.255.254.0` | `255.255.(11111110).00000000` |
# | **Bitwise AND** | `172.29.(11111000).00000000`  |
#
#
# So, the newtork address of 172.29.248 is ``172.29.248.0``
#
# - Given, 9 host bits (for /23), for the broadcast address all host bits = 1
# - Binary (set host bits to 1): ``172.29.11111001.11111111``
# - Broadcast address (decimal):``172.29.249.255``
#
# #### **Ques 20.** What is the first valid host on the subnetowork with a host 172.18.81.53. Given mask = 255.255.254.0?
#
# |  `172.18.81.53` | `172.18.(01010001).00110101`  |
# | --------------: | :---------------------------- |
# | `255.255.254.0` | `255.255.(11111110).00000000` |
# | **Bitwise AND** | `172.18.(01010000).00000000`  |
#
# So, then network address will be ``172.18.80.0``
# - First Host of this network will be ``172.18.80.1``
#
# #### **Ques. 21** Which subnet does host 172.25.90.254 belongs to. Given mask = 255.255.252.0
#
# |  `172.25.90.254` | `172.25.(01011010).00110101`  |
# | --------------: | :---------------------------- |
# | `255.255.252.0` | `255.255.(11111100).00000000` |
# | **Bitwise AND** | `172.25.(01011000).00000000`  |
#
# So, the (sub)network address will be "172.25.88.0``
